# %% [markdown]
# <a href="https://colab.research.google.com/github/NimishSinghChouhan/Smart-Bridge-AI/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q.1 Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0,4,size=(4, 4)), columns=list('ABCD'))

# %%
df
# Out:
#    A  B  C  D
# 0  3  3  0  1
# 1  3  1  0  0
# 2  3  3  1  2
# 3  2  3  0  1

# %% [markdown]
# Q.2 Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
 # Before renaming the columns
print(df.columns)
  
df.set_axis(['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4'], axis='columns', inplace=True)
# Out:
# Index(['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4'], dtype='object')
# <ipython-input-5-fa7f27f27a8f>:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4'], axis='columns', inplace=True)

# %%
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               3               3               0               1
# 1               3               1               0               0
# 2               3               3               1               2
# 3               2               3               0               1

# %% [markdown]
# Q.3 Find the descriptive statistics of the 'df' dataframe.

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count            4.00             4.0            4.00        4.000000
# mean             2.75             2.5            0.25        1.000000
# std              0.50             1.0            0.50        0.816497
# min              2.00             1.0            0.00        0.000000
# 25%              2.75             2.5            0.00        0.750000
# 50%              3.00             3.0            0.00        1.000000
# 75%              3.00             3.0            0.25        1.250000
# max              3.00             3.0            1.00        2.000000

# %% [markdown]
# Q.4 Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Q.5 Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
# There are 3 ways
df2 = df[["Random value 2","Random value 3"]] 
df2 = df.loc[:, ["Random value 2","Random value 3"]]
df2 = df.get(['Random value 2','Random value 3'])
df2
# Out:
#    Random value 2  Random value 3
# 0               3               0
# 1               1               0
# 2               3               1
# 3               3               0
