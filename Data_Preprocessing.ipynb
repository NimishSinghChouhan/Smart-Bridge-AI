# %% [markdown]
# <a href="https://colab.research.google.com/github/NimishSinghChouhan/Smart-Bridge-AI/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/insurance.csv')

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.head() # gives first 5
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail() # gives last 5
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape # 1338 records with 7 features/parameters
# Out:
# (1338, 7)

# %%
df.info() # to check the datatype of the parameters
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().any() #checking is there any missing field
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
df.isnull().sum() #gives the sum missing values
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#if null values are present in the numerical column
#if we have null values in the numerical column we have to replace it with a mean or median
#similarly if we have null values in the categorical column we have to replace it with mode

# %%
## df['age'].fillna(df['age'].median(),inplace =True)

## df['smoker'].fillna(df['smoker'].mode(),inplace =True)

# %%
 df.describe() # for numerical values
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# 25% - 1st quartile
#
# 50% - 2nd quartile (median value)
#
# 75% - 3rd quartile
#
# mean - summation of observation/ total no. of obsrvations
#
# 5 point summary in statistics - (min, 1st, 2nd, 3rd quartile and max)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.region.unique() # for categorical columns
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.smoker.value_counts() # for categorical columns
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-105-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# Visualisation-
#
# 1) Univariate analysis - taking 1 parameter and plotting
#
# 2) Bi-variate analysis - checking relation between 2
#
# 3) Multi-variate analysis - checking relation between more than 2

# %% [markdown]
# Univariate Analysis

# %%
sns.distplot(df.age)
# Out:
# <ipython-input-106-36725a16e635>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.age)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df.bmi)
# Out:
# <ipython-input-107-136d2c97b06d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.bmi)
# <Axes: xlabel='bmi', ylabel='Density'>

# %% [markdown]
# If the tail of the curve is more to -
#
# the right it is called right skewed,
#
# the left it is called left skewed
#
# when not to the right and left it is called balanced

# %%
plt.pie(df.smoker.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7bb6c49e70>,
# ...
#  [Text(-0.8801026332278259, 0.6598631335250117, ''),
#   Text(0.8801026332278258, -0.6598631335250118, '')])

# %%
plt.pie(df.smoker.value_counts(),[0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7bb6ca82b0>,
# ...
#  [Text(-0.9601119635212646, 0.7198506911181946, ''),
#   Text(0.8801026332278258, -0.6598631335250118, '')])

# %%
plt.pie(df.smoker.value_counts(),[0.1,0],labels=['NO','YES'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7bb6cd6800>,
# ...
#  [Text(-0.9601119635212646, 0.7198506911181946, 'NO'),
#   Text(0.8801026332278258, -0.6598631335250118, 'YES')])

# %%
plt.pie(df.smoker.value_counts(),[0.1,0],labels=['NO','YES'],autopct = "%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7bb6a3cbb0>,
# ...
#  [Text(-0.9601119635212646, 0.7198506911181946, 'NO'),
#   Text(0.8801026332278258, -0.6598631335250118, 'YES')],
#  [Text(-0.560065312054071, 0.4199129031522801, '79.5%'),
#   Text(0.48005598176063213, -0.3599253455590973, '20.5%')])

# %%
plt.pie(df.smoker.value_counts(),[0.1,0],labels=['NO','YES'],autopct = "%1.1f%%", colors=['red','yellow'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7bb6a63940>,
# ...
#  [Text(-0.9601119635212646, 0.7198506911181946, 'NO'),
#   Text(0.8801026332278258, -0.6598631335250118, 'YES')],
#  [Text(-0.560065312054071, 0.4199129031522801, '79.5%'),
#   Text(0.48005598176063213, -0.3599253455590973, '20.5%')])

# %%
plt.pie(df.smoker.value_counts(),[0.1,0],labels=['NO','YES'],autopct = "%1.1f%%", colors=['red','yellow'])
plt.title('SMOKER')
plt.show()

# %%
sns.barplot(x=df.region.value_counts().index,y=df.region.value_counts())
# Out:
# <Axes: ylabel='region'>

# %%
sns.lineplot(x= df.age, y=df.charges) # bivariate analysis
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x=df.bmi, y=df.charges)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
## Multivariate analysis

# %%
sns.scatterplot(x=df.age, y=df.charges)
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-120-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.heatmap(df.corr(),annot =True)
# Out:
# <ipython-input-121-8451b8490161>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot =True)
# <Axes: >

# %%
# z score, percentile, iqr - removal methods
# replacement method - median

# %%
sns.boxplot(df.bmi)
# Out:
# <Axes: >

# %% [markdown]
# Outlier Removal
#
# IQR - Inter quartile range
#
# IQR = Q3 - Q1
#
# Q1 = df.bmi.quantile(0.25)
#
# Q3 = df.bmi.quantile(0.75)

# %%
q1=df.bmi.quantile(.25)
q3=df.bmi.quantile(.75)

# %%
q1
# Out:
# 26.29625

# %%
q3
# Out:
# 34.69375

# %%
IQR = q3 - q1
IQR
# Out:
# 8.3975

# %%
upper_limit = q3+1.5*IQR
lower_limit = q1-1.5*IQR

# %%
df.median()
# Out:
# <ipython-input-129-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
df.shape
# Out:
# (1338, 7)

# %%
# Percentile

# %%
sns.boxplot(df.bmi)
# Out:
# <Axes: >

# %%
p99 = df.bmi.quantile(0.99) # percentile formula
p99
# Out:
# 46.40789999999996

# %%
# z score

# %%
from scipy import stats

# %%
bmi_zscore = stats.zscore(df.bmi)

# %%
bmi_zscore
# Out:
# 0      -0.453320
# 1       0.509621
# 2       0.383307
# 3      -1.305531
# 4      -0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336   -0.797813
# 1337   -0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
df_z = df[np.abs(bmi_zscore)<=3]

# %%
sns.boxplot(bmi_zscore)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1338, 7)

# %%
# Replacement of outliers using median

# %%
q1=df.bmi.quantile(.25)
q3=df.bmi.quantile(.75)

# %%
IQR = q3 - q1
IQR
# Out:
# 8.3975

# %%
upper_limit = q3+1.5*IQR
lower_limit = q1-1.5*IQR

# %%
df.median()
# Out:
# <ipython-input-146-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
